# %%
import numpy as np
import pandas as pd

# %% [markdown]
# DATA TYPES

# %%
df_kg=pd.read_csv("/content/drive/MyDrive/icmr.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_kg
# Out:
#       Patient_ID       Name     Sex  ... Tur Dhal  Vanaspati  Wheat
# 0              1  KAVERAMMA  FEMALE  ...     YES6        NaN   YES3
# 1              2  KALIYAIAH    MALE  ...      YES        NaN    NaN
# 2              3     SURESH    MALE  ...      YES        NaN    NaN
# 3              4      LAXMI  FEMALE  ...      YES        NaN    NaN
# 4              5      SHIVU    MALE  ...      NaN        NaN     NO
# ...          ...        ...     ...  ...      ...        ...    ...
# 1616        1617     GIRIJA  FEMALE  ...      NaN        NaN    NaN
# 1617        1618   SUBBAMMA  FEMALE  ...      NaN        NaN    NaN
# 1618        1619      LAXMI  FEMALE  ...      NaN        NaN    NaN
# 1619        1620  AVVAYAMMA  FEMALE  ...      NaN        NaN    NaN
# 1620        1621   KEMPAMMA  FEMALE  ...      NaN        NaN    NaN
#
# [1621 rows x 226 columns]

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# DATA SHAPE AND COLUMNS

# %%
df_kg.shape, df_kg.columns
# Out:
# ((1621, 226), Index(['Patient_ID', 'Name', 'Sex', 'DOB', 'Age', 'BirthOrder',
#         'MaritalStatus', 'MarriageType', 'ConsangunityDegree', 'FatherName',
#         ...
#         'Other Vegetables', 'Pulses/dhals', 'Ragi', 'Rice', 'Roots & Tubers',
#         'Seasonal fruits', 'Sugar & Jaggery', 'Tur Dhal', 'Vanaspati', 'Wheat'],
#        dtype='object', length=226))

# %% [markdown]
# LOCATION

# %%
df_kg.iloc[1,:]
# Out:
# Patient_ID                 2
# Name               KALIYAIAH
# Sex                     MALE
# DOB                      NaN
# Age                       55
#                      ...
# Seasonal fruits          YES
# Sugar & Jaggery          YES
# Tur Dhal                 YES
# Vanaspati                NaN
# Wheat                    NaN
# Name: 1, Length: 226, dtype: object

# %% [markdown]
# sample datas

# %%
df_kg.sample()
# Out:
#      Patient_ID   Name     Sex  DOB  ...  Sugar & Jaggery  Tur Dhal Vanaspati Wheat
# 903         904  PUTTI  FEMALE  NaN  ...              YES       YES       NaN   YES
#
# [1 rows x 226 columns]

# %% [markdown]
# DATA HEAD AND TAIL

# %%
df_kg.head(),df_kg.tail()
# Out:
# (   Patient_ID       Name     Sex  DOB  ...  Sugar & Jaggery  Tur Dhal Vanaspati Wheat
#  0           1  KAVERAMMA  FEMALE  NaN  ...             YES0      YES6       NaN  YES3
#  1           2  KALIYAIAH    MALE  NaN  ...              YES       YES       NaN   NaN
#  2           3     SURESH    MALE  NaN  ...              YES       YES       NaN   NaN
#  3           4      LAXMI  FEMALE  NaN  ...              YES       YES       NaN   NaN
#  4           5      SHIVU    MALE  NaN  ...              YES       NaN       NaN    NO
#
#  [5 rows x 226 columns],
#        Patient_ID       Name     Sex  ... Tur Dhal  Vanaspati  Wheat
#  1616        1617     GIRIJA  FEMALE  ...      NaN        NaN    NaN
#  1617        1618   SUBBAMMA  FEMALE  ...      NaN        NaN    NaN
#  1618        1619      LAXMI  FEMALE  ...      NaN        NaN    NaN
#  1619        1620  AVVAYAMMA  FEMALE  ...      NaN        NaN    NaN
#  1620        1621   KEMPAMMA  FEMALE  ...      NaN        NaN    NaN
#
# ...

# %% [markdown]
# **DATA** DESCRIBE

# %%
df_kg.describe().T
# Out:
#                 count        mean         std  ...    50%     75%     max
# Patient_ID     1621.0  811.000000  468.086708  ...  811.0  1216.0  1621.0
# Age            1621.0   35.196792   12.475611  ...   32.0    45.0    61.0
# BirthOrder     1621.0    2.597162    1.792637  ...    2.0     3.0    12.0
# FamilySize     1621.0    5.175817    2.446072  ...    5.0     6.0    24.0
# Adults_Twenty  1621.0    3.260950    1.553693  ...    3.0     4.0    10.0
# ...               ...         ...         ...  ...    ...     ...     ...
# CupB              0.0         NaN         NaN  ...    NaN     NaN     NaN
# CupC              0.0         NaN         NaN  ...    NaN     NaN     NaN
# CupD              0.0         NaN         NaN  ...    NaN     NaN     NaN
# CupE              0.0         NaN         NaN  ...    NaN     NaN     NaN
# Vanaspati         0.0         NaN         NaN  ...    NaN     NaN     NaN
#
# [110 rows x 8 columns]

# %% [markdown]
# NULL VALUS SUM

# %%
df_kg.isna().sum()
# Out:
# Patient_ID            0
# Name                  0
# Sex                   0
# DOB                1619
# Age                   0
#                    ...
# Seasonal fruits     632
# Sugar & Jaggery     624
# Tur Dhal            623
# Vanaspati          1621
# Wheat               635
# Length: 226, dtype: int64

# %% [markdown]
# DROP NULL VALUS

# %%
df_kg.dropna(axis=1,how='any').T
# Out:
#                                       0     ...             1620
# Patient_ID                               1  ...             1621
# Name                             KAVERAMMA  ...         KEMPAMMA
# Sex                                 FEMALE  ...           FEMALE
# Age                                     45  ...               58
# BirthOrder                               2  ...                4
# MaritalStatus                      Married  ...            WIDOW
# Familytype                         Nuclear  ...            Joint
# MotherTongue                     JENU NUDI  ...        JENU NUDI
# FamilySize                              11  ...                8
# Adults_Twenty                            7  ...                6
# Family_Males                             4  ...                3
# Family_Female                            3  ...                3
# Haadi                          HARALAHALLI  ...       NARALAPURA
# ...

# %% [markdown]
# DROP NULL VALUS, COLUMNS

# %%
df_kg.columns
# Out:
# Index(['Patient_ID', 'Name', 'Sex', 'DOB', 'Age', 'BirthOrder',
#        'MaritalStatus', 'MarriageType', 'ConsangunityDegree', 'FatherName',
#        ...
#        'Other Vegetables', 'Pulses/dhals', 'Ragi', 'Rice', 'Roots & Tubers',
#        'Seasonal fruits', 'Sugar & Jaggery', 'Tur Dhal', 'Vanaspati', 'Wheat'],
#       dtype='object', length=226)

# %% [markdown]
# IMPORT LIBRARIES

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
sns.set(style="white")

# %% [markdown]
# NUMBER OF GENDER

# %%
color= sns.color_palette()

int_level = df_kg['Sex'].value_counts()

plt.figure(figsize=(9,5))
sns.barplot(int_level.index,int_level.values,alpha=0.9, color=color[4])
plt.ylabel('number of occurrences',fontsize=12)
plt.xlabel('gender',fontsize=12)
plt.show()

# %% [markdown]
# NUMBER OF WORKS

# %%
color=sns.color_palette()

int_level = df_kg['Type_of_Work'].value_counts()

plt.figure(figsize=(9,5))
plt.xticks(rotation=90)
sns.barplot(int_level.index,int_level.values,alpha=0.9,color=color[2])
plt.ylabel('cesnumberoccurren of ',fontsize=12)
plt.xlabel('occupation',fontsize=12)
plt.show()

# %%
df_kg['Age_range']=np.where((df_kg['Age']>0) & (df_kg['Age']<=18),'0 -18','o') 
df_kg
# Out:
#       Patient_ID       Name     Sex  DOB  ...  Tur Dhal  Vanaspati Wheat Age_range
# 0              1  KAVERAMMA  FEMALE  NaN  ...      YES6        NaN  YES3         o
# 1              2  KALIYAIAH    MALE  NaN  ...       YES        NaN   NaN         o
# 2              3     SURESH    MALE  NaN  ...       YES        NaN   NaN         o
# 3              4      LAXMI  FEMALE  NaN  ...       YES        NaN   NaN         o
# 4              5      SHIVU    MALE  NaN  ...       NaN        NaN    NO         o
# ...          ...        ...     ...  ...  ...       ...        ...   ...       ...
# 1616        1617     GIRIJA  FEMALE  NaN  ...       NaN        NaN   NaN         o
# 1617        1618   SUBBAMMA  FEMALE  NaN  ...       NaN        NaN   NaN         o
# 1618        1619      LAXMI  FEMALE  NaN  ...       NaN        NaN   NaN         o
# 1619        1620  AVVAYAMMA  FEMALE  NaN  ...       NaN        NaN   NaN         o
# ...

# %%
df_kg['Age_range']=np.where((df_kg['Age']>0) & (df_kg['Age']<=18),'minor',df_kg['Age_range'])
df_kg['Age_range']=np.where((df_kg['Age']>=18) & (df_kg['Age']<=30),'young',df_kg['Age_range'])
df_kg['Age_range']=np.where((df_kg['Age']>30) & (df_kg['Age']<=45),'middle',df_kg['Age_range'])
df_kg['Age_range']=np.where((df_kg['Age']>45) & (df_kg['Age']<=60),'agedpeople',df_kg['Age_range'])
df_kg['Age_range']=np.where((df_kg['Age']>60) & (df_kg['Age']<=90),'older',df_kg['Age_range'])
df_kg
# Out:
#       Patient_ID       Name     Sex  DOB  ...  Tur Dhal  Vanaspati Wheat   Age_range
# 0              1  KAVERAMMA  FEMALE  NaN  ...      YES6        NaN  YES3      middle
# 1              2  KALIYAIAH    MALE  NaN  ...       YES        NaN   NaN  agedpeople
# 2              3     SURESH    MALE  NaN  ...       YES        NaN   NaN       young
# 3              4      LAXMI  FEMALE  NaN  ...       YES        NaN   NaN       young
# 4              5      SHIVU    MALE  NaN  ...       NaN        NaN    NO       young
# ...          ...        ...     ...  ...  ...       ...        ...   ...         ...
# 1616        1617     GIRIJA  FEMALE  NaN  ...       NaN        NaN   NaN      middle
# 1617        1618   SUBBAMMA  FEMALE  NaN  ...       NaN        NaN   NaN  agedpeople
# 1618        1619      LAXMI  FEMALE  NaN  ...       NaN        NaN   NaN      middle
# 1619        1620  AVVAYAMMA  FEMALE  NaN  ...       NaN        NaN   NaN      middle
# ...

# %% [markdown]
# SAMPLE OF AGE RANGE

# %%
df_kg['Age_range'].value_counts().plot(kind='pie',figsize=(5,5),autopct='%1.0f%%')

# %% [markdown]
# NUMBER OF AGE PEOPLES

# %%
int_level = df_kg['Age'].value_counts()

plt.figure(figsize=(9,5))
plt.xticks(rotation=90)
#clrs = ['grey' if (x < max('Age')) else 'red' for x in 'Age' ]
sns.barplot(int_level.index,int_level.values,palette = 'magma')
plt.ylabel('number of occurrences',fontsize=12)
plt.xlabel('Age',fontsize=12)
plt.show()

# %%
color=sns.color_palette()

int_level=df_kg['BirthOrder'].value_counts()

plt.figure(figsize=(9,5))
sns.barplot(int_level.index,int_level.values)
plt.ylabel('number of occurrences',fontsize=12)
plt.xlabel('BirthOrder',fontsize=12)
plt.show()

# %%
df1=df_kg.groupby(['Family_Males','Family_Female','Familytype'],as_index=False)['FamilySize'].sum()

# %%
df1
# Out:
#     Family_Males  Family_Female Familytype  FamilySize
# 0              0              0    Nuclear           0
# 1              0              1      Joint           4
# 2              0              1    Nuclear          53
# 3              0              2      Joint           9
# 4              0              2    Nuclear          31
# 5              0              3      Joint           3
# 6              0              4    Nuclear           7
# 7              1              0    Nuclear          13
# 8              1              1      Joint          75
# 9              1              1    Nuclear        2481
# 10             1              2      Joint         196
# 11             1              2    Nuclear         520
# 12             1              3      Joint          42
# 13             1              3    Nuclear         123
# 14             1              4    Nuclear          35
# 15             1              5      Joint           7
# ...

# %%
plt.figure(figsize=(20,20))
g=sns.catplot(data=df_kg,kind="bar",x="Family_Males",y="FamilySize",hue="Familytype",palette = 'magma')
plt.title("family")
# Out:
# Text(0.5, 1.0, 'family')

# %%
plt.figure(figsize=(20,20))
g=sns.catplot(data=df_kg,kind="bar",x="Family_Female",y="FamilySize",hue="Familytype",palette = 'magma')
plt.title("family")
# Out:
# Text(0.5, 1.0, 'family')

# %%
df2=df_kg['Sex'].unique()

# %%
df1=df_kg.groupby(['Sex'],as_index=False)['Employment'].sum()

# %%
df1
# Out:
#       Sex  Employment
# 0  FEMALE        2083
# 1    MALE        2053

# %% [markdown]
# WORKING

# %%
# Data to plot
labels = df1['Sex']
sizes = df1['Employment']
#colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1,0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, 
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
df1=df_kg.groupby(['Haadi','Taluk'],as_index=False)['Electricity'].sum()

# %%
df1.head()
# Out:
#                  Haadi   Taluk  Electricity
# 0   1st BLOCK NAGAPURA  HUNSUR           41
# 1  2ND BLOCK, NAGAPURA  HUNSUR            1
# 2  4th BLOCK, NAGAPURA  HUNSUR           47
# 3  5th BLOCK, NAGAPURA  HUNSUR           80
# 4  6TH BLOCK, NAGAPURA  HUNSUR            1

# %%
g=sns.relplot(x="Haadi",y="Taluk", hue="Electricity", data=df1,palette='tab10');
g.set_xticklabels(rotation=90)
g.fig.set_size_inches(20,10)


#plt.show()

# %%
df2=df_kg.groupby(['HouseType','HouseOwner','FuelCooking'],as_index=False)['CookingRoom'].sum()

# %%
df2
# Out:
#     HouseType  HouseOwner  FuelCooking  CookingRoom
# 0           0           0            0           13
# 1           0           0            1            2
# 2           0           2            0            6
# 3           0           2            1            2
# 4           2           0            0          631
# 5           2           0            1           19
# 6           2           0            2            1
# 7           2           2            0          594
# 8           2           2            1           23
# 9           2           2            2            2
# 10          4           0            0           89
# 11          4           0            1            1
# 12          4           2            0           73
# 13          4           2            1            2

# %%
g=sns.catplot(x='HouseType',y='HouseOwner',hue='CookingRoom',data=df2)
g.set_xticklabels(rotation=90)
g.fig.set_size_inches(10,7)

# %%
df_kg['BP_Value'].value_counts().plot(kind='pie',figsize=(5,5),autopct='%1.0f%%')

# %%
df3=df_kg.groupby(['Family_Males','FamilySize'],as_index=False)['BP_Value'].sum() 
df3
# Out:
#     Family_Males  FamilySize                                           BP_Value
# 0              0           0   NormalNormalPrehypertensionPrehypertensionNormal
# 1              0           1  Hypertension, Stage 1NormalNormalPrehypertensi...
# 2              0           2  Hypertension, Stage 1PrehypertensionNormalNorm...
# 3              0           3  NormalHypertension, Stage 1NormalNormalNormalN...
# 4              0           4  NormalPrehypertensionNormalNormalNormalNormalN...
# ..           ...         ...                                                ...
# 56             5          16                                             Normal
# 57             5          17                              Hypertension, Stage 1
# 58             6          10                                             Normal
# 59             6          12                  NormalPrehypertensionNormalNormal
# 60             7          14                                    Prehypertension
#
# ...

# %%
plt.figure(figsize=(20,20))
g=sns.catplot(data=df_kg,kind="bar",x="Family_Female",y="FamilySize",hue="BP_Value")
plt.title("family")
# Out:
# Text(0.5, 1.0, 'family')

# %%
df3=df_kg.groupby(['Family_Males','FamilySize'],as_index=False)['BP_Value'].sum() 
df3
# Out:
#     Family_Males  FamilySize                                           BP_Value
# 0              0           0   NormalNormalPrehypertensionPrehypertensionNormal
# 1              0           1  Hypertension, Stage 1NormalNormalPrehypertensi...
# 2              0           2  Hypertension, Stage 1PrehypertensionNormalNorm...
# 3              0           3  NormalHypertension, Stage 1NormalNormalNormalN...
# 4              0           4  NormalPrehypertensionNormalNormalNormalNormalN...
# ..           ...         ...                                                ...
# 56             5          16                                             Normal
# 57             5          17                              Hypertension, Stage 1
# 58             6          10                                             Normal
# 59             6          12                  NormalPrehypertensionNormalNormal
# 60             7          14                                    Prehypertension
#
# ...

# %%
plt.figure(figsize=(20,20))
g=sns.catplot(data=df_kg,kind="bar",x="Family_Males",y="FamilySize",hue="BP_Value")
plt.title("family")
# Out:
# Text(0.5, 1.0, 'family')

# %%
df_kg['AgriculturalLand'].value_counts().plot(kind='pie',figsize=(5,5),autopct='%1.0f%%')

# %%
df_kg['IrrigatedLand'].value_counts().plot(kind='pie',figsize=(5,5),autopct='%1.0f%%')

# %%
df3=df_kg.groupby(['Family_Net_income'],as_index=False)['Sex'].sum()

# %%
df3.head()
# Out:
#    Family_Net_income                                             Sex
# 0                  0  MALEFEMALEFEMALEMALEMALEFEMALEFEMALEMALEFEMALE
# 1                300                                          FEMALE
# 2                400                                            MALE
# 3                750                                          FEMALE
# 4                800                                      MALEFEMALE

# %%
ax = sns.barplot(x="Family_Net_income", y="Sex",data=df3.head())

# %% [markdown]
# BMI VALUES

# %%
df8=df_kg.groupby(['Height','Weight'],as_index=False)['BMI'].sum()
df8
# Out:
#      Height  Weight    BMI
# 0         0       0   0.00
# 1       100      47  47.00
# 2       105      30  27.21
# 3       110      60  49.59
# 4       110      70  57.85
# ..      ...     ...    ...
# 651     180      51  15.74
# 652     180      53  16.36
# 653     180      60  18.52
# 654     180      61  18.83
# 655     182      55  16.60
#
# [656 rows x 3 columns]

# %%
plt.figure(figsize=(20,20))
sns.jointplot(data=df_kg, x="Height", y="Weight", hue="BMI")

# %%
# plt.figure(figsize=(4,4))

# sns.boxplot('LiveStock',data=df_kg.head())

# %%
df5=df_kg.groupby(['Education'],as_index=False)['Employment'].sum()
df5.head()
# Out:
#    Education  Employment
# 0          0        2187
# 1          1         300
# 2          2         996
# 3          3         602
# 4          4          51

# %%
p = sns.jointplot(data=df5,x='Education', y='Employment',kind='reg')

# %%
# import matplotlib.pyplot as plt
# import pandas as pd
# import seaborn as sns 
# import numpy as np

# %%
# df_kg['Age_range']=np.where((df_kg['Age']>0) & (df_kg['Age']<=18),'0 -18','o')

# %%
# df_kg['Age_range']=np.where((df_kg['Age']>0) & (df_kg['Age']<=18),'minor',df_kg['Age_range'])
# df_kg['Age_range']=np.where((df_kg['Age']>=18) & (df_kg['Age']<=30),'young',df_kg['Age_range'])
# df_kg['Age_range']=np.where((df_kg['Age']>30) & (df_kg['Age']<=45),'middle',df_kg['Age_range'])
# df_kg['Age_range']=np.where((df_kg['Age']>45) & (df_kg['Age']<=60),'agedpeople',df_kg['Age_range'])
# df_kg['Age_range']=np.where((df_kg['Age']>60) & (df_kg['Age']<=90),'older',df_kg['Age_range'])

# %%
df_kg['BMI_range']=np.where((df_kg['BMI']>0) & (df_kg['BMI']<=18),'0 -18','o')

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_kg.head(2)
# Out:
#    Patient_ID       Name     Sex  DOB  ...  Vanaspati  Wheat   Age_range BMI_range
# 0           1  KAVERAMMA  FEMALE  NaN  ...        NaN   YES3      middle         o
# 1           2  KALIYAIAH    MALE  NaN  ...        NaN    NaN  agedpeople         o
#
# [2 rows x 228 columns]

# %%
df_kg.iplot
# Out:
# <bound method _iplot of       Patient_ID       Name     Sex  DOB  ...  Vanaspati  Wheat   Age_range BMI_range
# 0              1  KAVERAMMA  FEMALE  NaN  ...        NaN   YES3      middle         o
# 1              2  KALIYAIAH    MALE  NaN  ...        NaN    NaN  agedpeople         o
# 2              3     SURESH    MALE  NaN  ...        NaN    NaN       young         o
# 3              4      LAXMI  FEMALE  NaN  ...        NaN    NaN       young         o
# 4              5      SHIVU    MALE  NaN  ...        NaN     NO       young         o
# ...          ...        ...     ...  ...  ...        ...    ...         ...       ...
# 1616        1617     GIRIJA  FEMALE  NaN  ...        NaN    NaN      middle         o
# 1617        1618   SUBBAMMA  FEMALE  NaN  ...        NaN    NaN  agedpeople         o
# 1618        1619      LAXMI  FEMALE  NaN  ...        NaN    NaN      middle     0 -18
# 1619        1620  AVVAYAMMA  FEMALE  NaN  ...        NaN    NaN      middle         o
# ...
