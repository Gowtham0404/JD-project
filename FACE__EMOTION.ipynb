# %% [markdown]
# <a href="https://colab.research.google.com/github/Gowtham0404/JD-project/blob/main/FACE__EMOTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###FACE AND EMOTION DETECTION

# %% [markdown]
# ##OBJECT:
# To Prodict face and Emotion deterction. In this, we will show what we are doing to use the facial expression
# (eg)Happy,sad,fear,Brainstorming.....

# %% [markdown]
# ##I will download the required data

# %% [markdown]
# **pip install tensorflow-gpu**
#
# This guide covers GPU support and installation steps for the latest stable TensorFlow release. ... pip install tensorflow-gpu

# %%
pip install tensorflow

# %% [markdown]
# **pip install deepface**
#
# Deepface is a lightweight face recognition and facial attribute analysis (age, gender, emotion and race) framework for python.

# %%
pip install deepface
# Out:
# ...
#      |████████████████████████████████| 61 kB 6.6 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 2.3 MB 19.3 MB/s
# ...
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14273 sha256=7175f75934af8e7076624c105178766efbcb8daadce43112731879a6b5bad51b
#   Stored in directory: /root/.cache/pip/wheels/8c/17/ff/58721d1fabdb87c21a0529948cf39e2be9af90ddbe4ad65944
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %% [markdown]
# **I have made the necessary library**

# %%
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import numpy

# %% [markdown]
# **import tensorflow as tf**
#
#  tf.Graph() set g1 as default to add tensors to this graph using default methord
#
# **import cv2**
#
# OpenCV-Python is a library of Python bindings designed to solve computer vision problems. cv2. imread() method loads an image from the specified file

# %%
# from google.colab.patches import cv2_imshow
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %% [markdown]
# Deepface is a lightweight face recognition and facial attribute analysis (age, gender, emotion and race) framework for python.

# %% [markdown]
# first step using cv2 read the image path

# %%
img = cv2.imread('/content/drive/MyDrive/1.webp')

# %% [markdown]
# Show the image

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# Using the DeepFace training model

# %%
prediction = DeepFace.analyze(img)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 171MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 100%|██████████| 539M/539M [00:02<00:00, 201MB/s]
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# gender_model_weights.h5 will be downloaded...
# 100%|██████████| 537M/537M [00:05<00:00, 100MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# ...

# %% [markdown]
# Prediction the model

# %%
prediction
# Out:
# {'age': 30,
#  'dominant_emotion': 'happy',
#  'dominant_race': 'white',
#  'emotion': {'angry': 0.00333345087710768,
#   'disgust': 3.5325260078211684e-09,
#   'fear': 1.648266240954399,
#   'happy': 98.3329713344574,
#   'neutral': 0.014375238970387727,
#   'sad': 0.0008767204235482495,
#   'surprise': 0.00017843672139861155},
#  'gender': 'Man',
#  'race': {'asian': 0.7497129477389424,
#   'black': 0.01078824416892382,
#   'indian': 0.15914840408181571,
#   'latino hispanic': 13.882502250820533,
#   'middle eastern': 5.953711253625825,
#   'white': 79.24413557315681},
#  'region': {'h': 214, 'w': 214, 'x': 281, 'y': 92}}

# %% [markdown]
# prediction type this is dict

# %%
type(prediction)
# Out:
# dict

# %% [markdown]
# Check the prediction model(dominant_emotion,gemder)

# %%
prediction['dominant_emotion']
# Out:
# 'happy'

# %%
prediction['gender']
# Out:
# 'Man'

# %% [markdown]
# **We are trying to draw a trctangle across the face**
#
# Cascade function using (haarcascade_frontalface_default.xml)

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  #print (facecasade.emty)
faces = face_cascade.detectMultiScale(gray, 1.1, 4)
  #Dreaw a rectangle around faces
for(x,y,w,h) in faces:
   cv2.rectangle(img, (x,y), (x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

# Use putText() mdthod for
# inserting text on video
cv2.putText(img,
            prediction['dominant_emotion'],
            (0,50),
            font, 1,
            (0,0,255),
            2,
            cv2.LINE_4);

# %% [markdown]
# **Emotion HAPPY**

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('/content/sad_on.jpg')

# %% [markdown]
# **Emotion SAD**

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.75it/s]

# %%
prediction
# Out:
# {'age': 29,
#  'dominant_emotion': 'neutral',
#  'dominant_race': 'white',
#  'emotion': {'angry': 0.07678339482670396,
#   'disgust': 5.92721740379505e-09,
#   'fear': 1.6007105842656246,
#   'happy': 1.6192434314859725e-05,
#   'neutral': 78.68939511116714,
#   'sad': 19.426926638300813,
#   'surprise': 0.2061691490885108},
#  'gender': 'Woman',
#  'race': {'asian': 0.08213780238293111,
#   'black': 0.007228219328681007,
#   'indian': 0.044825024087913334,
#   'latino hispanic': 6.748330593109131,
#   'middle eastern': 3.6583933979272842,
#   'white': 89.45908546447754},
#  'region': {'h': 300, 'w': 300, 'x': 55, 'y': 3}}

# %%
img = cv2.imread('/content/crinhg.jpg')

# %% [markdown]
# **Emotion Fear**

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
prediction = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.37it/s]

# %%
prediction
# Out:
# {'age': 32,
#  'dominant_emotion': 'happy',
#  'dominant_race': 'latino hispanic',
#  'emotion': {'angry': 0.7492817919273252,
#   'disgust': 0.01556389708639068,
#   'fear': 2.318605918801184,
#   'happy': 88.91847067585412,
#   'neutral': 0.039081053693022054,
#   'sad': 6.593140607663429,
#   'surprise': 1.3658597948169586},
#  'gender': 'Woman',
#  'race': {'asian': 24.786965536294314,
#   'black': 1.6179957460162488,
#   'indian': 10.407620543695721,
#   'latino hispanic': 30.35299958902595,
#   'middle eastern': 17.3868055574182,
#   'white': 15.447613027549567},
#  'region': {'h': 452, 'w': 452, 'x': 46, 'y': 112}}

# %% [markdown]
# ###REAL TIME VIDEO DEMO FOR FACE EMOTION RECOGNITION
#
# > Indented block

# %%
import cv2 ##pip instal opencv-python
 ##pip instal opencv-python fullpackage
from deepface import DeepFace ##pip instal depface

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(0)
 ##chek if the webcam is opened correctly 
if not cap.isOpened():
  cap = cv2.VideoCapture(0)
if not cap.isOpened():
  raise (IOError("Cannot open webcam"))

while True:
    ret,frame = cap.read()#read one image frome a video
    result = DeepFace.analyze(frame, actions=['emotion'])

    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    ##print facecasced.empty()

    faces = face_cascade.detectMultiScale(gray, 1.1, 4)

    ##Draw a rectangel around the face
    for(x,y,w,h) in faces:
      cv2.rectangle(img, (x,y), (x+w,y+h),(0,255,0),2)

    font = cv2.FONT_HERSHEY_SIMPLEX

    ## Use putText() mdthod for
    ## inserting text on video

    cv2.putText(img,
                prediction['dominant_emotion'],
                (0,50),
                font, 1,
                (0,0,255),
                2,
                cv2.LINE_4)
    cv2.imshow('Demo video',frame)

    if cv2.waitKey(2) & 0xFF == ord('q'):
      break

cap.release()
cv2.destroyAllWindows()
